# %%
import os
import sc2
from sc2 import run_game, maps, Race, Difficulty, position, Result
from sc2.player import Bot, Computer
from sc2.constants import NEXUS, PROBE, PYLON, ASSIMILATOR, GATEWAY, \
                        CYBERNETICSCORE, STARGATE, VOIDRAY, OBSERVER, ROBOTICSFACILITY
import random
from collections import defaultdict
import cv2
import numpy as np
import time
import pprint

#sc2path = os.path.abspath('C:\\sc2\\StarCraftII')
#print(sc2path)
#os.environ["SC2PATH"] = sc2path

VERBOSE = True


class JackyBot(sc2.BotAI):
    def __init__(self):
        #13 min : 2184 iterations
        # 1 min :  168 iterations
        self.IT_PER_MIN = 168.0
        self.MAX_WORKERS = (16 + 6) * 4
        self.do_something_after = 0
        self.waitLine = defaultdict(lambda: 0)
        self.train_data = []
        self.custom_game_state = np.zeros(10)

    def on_end(self, game_result):
        print('--- on_end called ---')
        print("Result: ", game_result)

        fileName = str(int(time.time()))

        if game_result == Result.Victory:
            np.save("train_data/victory/{}.npy".format(fileName),
                    np.array(self.train_data))
        elif game_result == Result.Defeat:
            np.save("train_data/defeat/{}.npy".format(fileName),
                    np.array(self.train_data))
        else:
            #does it happens?
            np.save("train_data/other/debug.txt", np.array(game_result))
            np.save("train_data/other/{}.npy".format(fileName),
                    np.array(self.train_data))
        #closing opencv window
        cv2.destroyAllWindows()

# %%
class JackyBot(JackyBot):
    async def on_step(self, iteration):
        self.iteration = iteration
        await self.scout()
        await self.distribute_workers()
        await self.build_workers()
        await self.build_pylons()
        await self.build_assimilators()
        await self.expand()
        await self.offensive_force_buildings()
        await self.build_offensive_force()
        await self.intel()
        await self.attack()

# %%
class JackyBot(JackyBot):
    def random_location_variance(self, enemy_start_location):
        x = enemy_start_location[0]
        y = enemy_start_location[1]

        x += ((random.randrange(-20, 20)) / 100) * enemy_start_location[0]
        y += ((random.randrange(-20, 20)) / 100) * enemy_start_location[1]

        if x < 0:
            x = 0
        if y < 0:
            y = 0
        if x > self.game_info.map_size[0]:
            x = self.game_info.map_size[0]
        if y > self.game_info.map_size[1]:
            y = self.game_info.map_size[1]

        go_to = position.Point2(position.Pointlike((x, y)))
        return go_to

# %%
class JackyBot(JackyBot):
    async def scout(self):
        if len(self.units(OBSERVER)) > 0:
            scout = self.units(OBSERVER)[0]
            if scout.is_idle:
                if self.iteration > self.waitLine['scout']:
                    w = 3 * (self.IT_PER_MIN / 60
                             )  #IT_PER_MINipm/60*3 = 3 seconds wait
                    self.waitLine['scout'] = self.iteration + w
                    #after w time passed with scout waiting idle
                    enemy_location = self.enemy_start_locations[0]
                    move_to = self.random_location_variance(enemy_location)
                    #print("moving probe to: ", move_to)
                    #print("waiting from it.", self.iteration," to it.",self.waitLine['scout'])
                    await self.do(scout.move(move_to))
            else:
                #scout bussy, so adding to wait just while iddle
                self.waitLine['scout'] += 1
        else:
            for rf in self.units(ROBOTICSFACILITY).ready.noqueue:
                if self.can_afford(OBSERVER) and self.supply_left >= 1:
                    await self.do(rf.train(OBSERVER))

# %%
class JackyBot(JackyBot):
    def colorGrading(self, n):
        print("")

# %% [markdown]
# # TODO
# ## prepare data for training
# # x: game state
#
#
# #### self resources
# 1.- self.iteration
# 2.- self.mineral
# 3.- self.vespene
# 4.- self.supply_left
# 5.- self.supply_cap
# #### self units
# 6.- self.units(PROBE)
# 7.- self.units(VOIDRAY)
# #### enemy units
# 8.- len(self.known_enemy_structures)
# 9.-  len(self.known_enemy_units) #workers
# 10.- len(self.known_enemy_units) #military
#
#
#
#
#
#
#
# # y: choose attack action
#
# ## [0, 0, 0, 1]
#
# ######  ["wait 10 secs",
#
# ######    "attack closer unit",
#
# ######    "attack structures",
#
# ######    "attack start location"]

# %%
class JackyBot(JackyBot):
    async def intel(self):
        #### self resources
        self.custom_game_state[0] = self.iteration / 3360.  #20 mins
        self.custom_game_state[1] = self.minerals / 3000
        self.custom_game_state[2] = self.vespene / 3000
        self.custom_game_state[3] = self.supply_left / 200
        self.custom_game_state[4] = self.supply_cap / 200
        #### self units
        self.custom_game_state[5] = len(self.workers) / 200
        self.custom_game_state[6] = len(self.units(VOIDRAY)) / 200
        #### enemy units
        self.custom_game_state[7] = len(self.known_enemy_structures) / 100
        worker_names = ["probe", "scv", "drone"]
        for enemy_unit in self.known_enemy_units.not_structure:
            if enemy_unit.name.lower() in worker_names:
                self.custom_game_state[8] += 1  #workers
            else:
                #not worker, not building
                self.custom_game_state[9] += 1
        self.custom_game_state[8] /= 200
        self.custom_game_state[9] /= 200
        if VERBOSE:
            if self.iteration > self.waitLine['intel']:
                #print game state every 10 seconds
                self.printGameState()
                self.waitLine['intel'] = self.iteration + 28

# %%
class JackyBot(JackyBot):
    def printGameState(self):
        '''for debugging purpuses'''
        descriptions = [
            ' 0.- self.iteration', ' 1.- self.mineral  ',
            ' 2.- self.vespene  ', ' 3.- self.supply_left',
            ' 4.- self.supply_cap ', ' 5.- self.units(PROBE)  ',
            ' 6.- self.units(VOIDRAY)',
            ' 7.- len(self.known_enemy_structures)     ',
            ' 8.- len(self.known_enemy_units) #workers ',
            ' 9.- len(self.known_enemy_units) #military'
        ]
        for desc, value in zip(descriptions, self.custom_game_state):
            print(desc, ': ', value)

# %%
class JackyBot(JackyBot):
    async def intelasd(self):
        print("Iteration: ", self.iteration)
        #print("map size: ",self.game_info.map_size)
        game_data = np.zeros(
            (self.game_info.map_size[1], self.game_info.map_size[0], 3),
            np.uint8)
        # UNIT: [SIZE, (BGR COLOR)]
        '''from sc2.constants import NEXUS, PROBE, PYLON, ASSIMILATOR, GATEWAY, \
           CYBERNETICSCORE, STARGATE, VOIDRAY'''
        draw_dict = {
            NEXUS: [2, 1 / 9 * 255],
            PYLON: [2, 2 / 9 * 255],
            PROBE: [2, 3 / 9 * 255],
            ASSIMILATOR: [2, 4 / 9 * 255],
            GATEWAY: [2, 5 / 9 * 255],
            CYBERNETICSCORE: [2, 6 / 9 * 255],
            STARGATE: [2, 7 / 9 * 255],
            ROBOTICSFACILITY: [2, 8 / 9 * 255],
            VOIDRAY: [2, 9 / 9 * 255],
            #OBSERVER: [3, (255, 255, 255)],
        }

        for unit_type in draw_dict:
            for unit in self.units(unit_type).ready:
                pos = unit.position
                #cv2.circle(game_data, (int(pos[0]), int(pos[1])), draw_dict[unit_type][0], draw_dict[unit_type][1], -1)

        main_base_names = ["nexus", "supplydepot", "hatchery"]
        for enemy_building in self.known_enemy_structures:
            pos = enemy_building.position
            #if enemy_building.name.lower() not in main_base_names:
            #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 5, (200, 50, 212), -1)
        for enemy_building in self.known_enemy_structures:
            pos = enemy_building.position
            #if enemy_building.name.lower() in main_base_names:
            #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 15, (0, 0, 255), -1)

        for enemy_unit in self.known_enemy_units:

            if not enemy_unit.is_structure:
                worker_names = ["probe", "scv", "drone"]
                # if that unit is a PROBE, SCV, or DRONE... it's a worker
                pos = enemy_unit.position
                #if enemy_unit.name.lower() in worker_names:
                #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 1, (55, 0, 155), -1)
                #else:
                #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 3, (50, 0, 215), -1)

        for obs in self.units(OBSERVER).ready:
            pos = obs.position
            #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 1, (255, 255, 255), -1)

        line_max = 50
        mineral_ratio = self.minerals / 1500
        if mineral_ratio > 1.0:
            mineral_ratio = 1.0

        vespene_ratio = self.vespene / 1500
        if vespene_ratio > 1.0:
            vespene_ratio = 1.0

        population_ratio = self.supply_left / self.supply_cap
        if population_ratio > 1.0:
            population_ratio = 1.0

        plausible_supply = self.supply_cap / 200.0

        military_weight = len(
            self.units(VOIDRAY)) / (self.supply_cap - self.supply_left)
        if military_weight > 1.0:
            military_weight = 1.0

        #cv2.line(game_data, (0, 19), (int(line_max*military_weight), 19), (250, 250, 200), 3)  # worker/supply ratio
        #cv2.line(game_data, (0, 15), (int(line_max*plausible_supply), 15), (220, 200, 200), 3)  # plausible supply (supply/200.0)
        #cv2.line(game_data, (0, 11), (int(line_max*population_ratio), 11), (150, 150, 150), 3)  # population ratio (supply_left/supply)
        #cv2.line(game_data, (0, 7), (int(line_max*vespene_ratio), 7), (210, 200, 0), 3)  # gas / 1500
        #cv2.line(game_data, (0, 3), (int(line_max*mineral_ratio), 3), (0, 255, 25), 3)  # minerals minerals/1500

        # flip horizontally to make our final fix in visual representation:
        self.custom_game_state = np.zeros(10)

        #if not HEADLESS:
        #resized = cv2.resize(self.flipped, dsize=None, fx=2, fy=2)
        #cv2.imshow('Intel', resized)
        #cv2.waitKey(1)

# %%
class JackyBot(JackyBot):
    async def intelOLD(self):
        #print("map size: ",self.game_info.map_size)
        game_data = np.zeros(
            (self.game_info.map_size[1], self.game_info.map_size[0], 3),
            np.uint8)
        # UNIT: [SIZE, (BGR COLOR)]
        '''from sc2.constants import NEXUS, PROBE, PYLON, ASSIMILATOR, GATEWAY, \
           CYBERNETICSCORE, STARGATE, VOIDRAY'''
        draw_dict = {
            NEXUS: [2, 1 / 9 * 255],
            PYLON: [2, 2 / 9 * 255],
            PROBE: [2, 3 / 9 * 255],
            ASSIMILATOR: [2, 4 / 9 * 255],
            GATEWAY: [2, 5 / 9 * 255],
            CYBERNETICSCORE: [2, 6 / 9 * 255],
            STARGATE: [2, 7 / 9 * 255],
            ROBOTICSFACILITY: [2, 8 / 9 * 255],
            VOIDRAY: [2, 9 / 9 * 255],
            #OBSERVER: [3, (255, 255, 255)],
        }

        for unit_type in draw_dict:
            for unit in self.units(unit_type).ready:
                pos = unit.position
                #cv2.circle(game_data, (int(pos[0]), int(pos[1])), draw_dict[unit_type][0], draw_dict[unit_type][1], -1)

        main_base_names = ["nexus", "supplydepot", "hatchery"]
        for enemy_building in self.known_enemy_structures:
            pos = enemy_building.position
            #if enemy_building.name.lower() not in main_base_names:
            #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 5, (200, 50, 212), -1)
        for enemy_building in self.known_enemy_structures:
            pos = enemy_building.position
            #if enemy_building.name.lower() in main_base_names:
            #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 15, (0, 0, 255), -1)

        for enemy_unit in self.known_enemy_units:

            if not enemy_unit.is_structure:
                worker_names = ["probe", "scv", "drone"]
                # if that unit is a PROBE, SCV, or DRONE... it's a worker
                pos = enemy_unit.position
                #if enemy_unit.name.lower() in worker_names:
                #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 1, (55, 0, 155), -1)
                #else:
                #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 3, (50, 0, 215), -1)

        for obs in self.units(OBSERVER).ready:
            pos = obs.position
            #cv2.circle(game_data, (int(pos[0]), int(pos[1])), 1, (255, 255, 255), -1)

        line_max = 50
        mineral_ratio = self.minerals / 1500
        if mineral_ratio > 1.0:
            mineral_ratio = 1.0

        vespene_ratio = self.vespene / 1500
        if vespene_ratio > 1.0:
            vespene_ratio = 1.0

        population_ratio = self.supply_left / self.supply_cap
        if population_ratio > 1.0:
            population_ratio = 1.0

        plausible_supply = self.supply_cap / 200.0

        military_weight = len(
            self.units(VOIDRAY)) / (self.supply_cap - self.supply_left)
        if military_weight > 1.0:
            military_weight = 1.0

        #cv2.line(game_data, (0, 19), (int(line_max*military_weight), 19), (250, 250, 200), 3)  # worker/supply ratio
        #cv2.line(game_data, (0, 15), (int(line_max*plausible_supply), 15), (220, 200, 200), 3)  # plausible supply (supply/200.0)
        #cv2.line(game_data, (0, 11), (int(line_max*population_ratio), 11), (150, 150, 150), 3)  # population ratio (supply_left/supply)
        #cv2.line(game_data, (0, 7), (int(line_max*vespene_ratio), 7), (210, 200, 0), 3)  # gas / 1500
        #cv2.line(game_data, (0, 3), (int(line_max*mineral_ratio), 3), (0, 255, 25), 3)  # minerals minerals/1500

        # flip horizontally to make our final fix in visual representation:
        self.flipped = cv2.flip(game_data, 0)

        #if not HEADLESS:
        #resized = cv2.resize(self.flipped, dsize=None, fx=2, fy=2)
        #cv2.imshow('Intel', resized)
        #cv2.waitKey(1)

# %%
class JackyBot(JackyBot):
    def moreWorkersNeeded(self):
        #check if more workers are needed
        if (len(self.units(PROBE)) < len(self.units(NEXUS))*(16+6)) and\
           (len(self.units(PROBE)) < self.MAX_WORKERS) and\
            self.can_afford(PROBE):
            return True
        else:
            return False

# %%
class JackyBot(JackyBot):
    async def build_workers(self):
        if self.moreWorkersNeeded():
            for nexus in self.units(NEXUS).ready.noqueue:
                #yes, again
                if nexus.assigned_harvesters < 16:
                    if self.moreWorkersNeeded():
                        await self.do(nexus.train(PROBE))
                    else:
                        break

# %%
class JackyBot(JackyBot):
    async def build_pylons(self):
        if self.supply_left < 8 and not self.already_pending(PYLON):
            nexuses = self.units(NEXUS).ready
            if nexuses.exists:
                if self.can_afford(PYLON):
                    await self.build(PYLON, near=nexuses.first)

# %%
class JackyBot(JackyBot):
    async def build_assimilators(self):
        for nexus in self.units(NEXUS).ready:
            vaspenes = self.state.vespene_geyser.closer_than(15.0, nexus)
            for vaspene in vaspenes:
                if not self.can_afford(ASSIMILATOR):
                    break
                worker = self.select_build_worker(vaspene.position)
                if worker is None:
                    break
                if not self.units(ASSIMILATOR).closer_than(1.0,
                                                           vaspene).exists:
                    await self.do(worker.build(ASSIMILATOR, vaspene))

# %%
class JackyBot(JackyBot):
    async def expand(self):
        if self.units(NEXUS).amount < ((float(self.iteration)/self.IT_PER_MIN)/2) and\
           self.can_afford(NEXUS):
            await self.expand_now()

# %%
class JackyBot(JackyBot):
    async def offensive_force_buildings(self):
        #print(self.iteration / self.IT_PER_MIN)
        if self.units(PYLON).ready.exists:
            pylon = self.units(PYLON).ready.random

            if self.units(
                    GATEWAY).ready.exists and not self.units(CYBERNETICSCORE):
                if self.can_afford(
                        CYBERNETICSCORE
                ) and not self.already_pending(CYBERNETICSCORE):
                    await self.build(CYBERNETICSCORE, near=pylon)

            elif len(self.units(GATEWAY)) < 1:
                if self.can_afford(
                        GATEWAY) and not self.already_pending(GATEWAY):
                    await self.build(GATEWAY, near=pylon)

            if self.units(CYBERNETICSCORE).ready.exists:
                if len(self.units(ROBOTICSFACILITY)) < 1:
                    if self.can_afford(
                            ROBOTICSFACILITY
                    ) and not self.already_pending(ROBOTICSFACILITY):
                        await self.build(ROBOTICSFACILITY, near=pylon)

            if self.units(CYBERNETICSCORE).ready.exists:
                if len(self.units(STARGATE)) < (
                        self.iteration / self.IT_PER_MIN):
                    if self.can_afford(
                            STARGATE) and not self.already_pending(STARGATE):
                        await self.build(STARGATE, near=pylon)

# %%
class JackyBot(JackyBot):
    async def build_offensive_force(self):
        for sg in self.units(STARGATE).ready.noqueue:
            if self.can_afford(VOIDRAY) and self.supply_left >= 4:
                await self.do(sg.train(VOIDRAY))

# %%
#attack-cell
class JackyBot(JackyBot):
    async def attack(self):
        if len(self.units(VOIDRAY).idle) > 0:
            choice = random.randrange(0, 4)
            target = False
            if self.iteration > self.do_something_after:
                if choice == 0:
                    # no attack, wait 10 secs
                    #wait = random.randrange(20, IT_PER_MIN)
                    wait = self.IT_PER_MIN / 6  # 10secs
                    self.do_something_after = self.iteration + wait
                elif choice == 1:
                    #attack_unit_closest_nexus
                    if len(self.known_enemy_units) > 0:
                        #startLoc = self.start_location
                        #self.game_info.map_size: 200x176
                        #screen diagonal: 266
                        #halfMap = 133
                        #if self.known_enemy_units.closer_than(halfMap, startLoc):
                        target = self.known_enemy_units.closest_to(
                            self.start_location)
                        #target = self.known_enemy_units.closest_to(nexus)
                elif choice == 2:
                    #attack enemy structures
                    if len(self.known_enemy_structures) > 0:
                        target = random.choice(self.known_enemy_structures)
                elif choice == 3:
                    #attack_enemy_start
                    target = self.enemy_start_locations[0]

                if target:
                    for vr in self.units(VOIDRAY).idle:
                        await self.do(vr.attack(target))

                y = np.zeros(4)
                y[choice] = 1
                self.train_data.append([self.custom_game_state, y])
                if VERBOSE:
                    print(y, [
                        "wait 10 secs   ", "at. closer unit",
                        "at. structures  ", "at. start location"
                    ][choice])

# %%
run_game(
    maps.get("AbyssalReefLE"),
    [Bot(Race.Protoss, JackyBot()),
     Computer(Race.Terran, Difficulty.Easy)],
    realtime=False)
# Out:
# INFO:sc2.protocol:Client status changed to Status.launched (was None)
# INFO:sc2.controller:Creating new game
# INFO:sc2.controller:Map:     AbyssalReefLE
# INFO:sc2.controller:Players: Bot(Race.Protoss, <__main__.JackyBot object at 0x000001E35AE30F60>), Computer(Race.Terran, Difficulty.Easy)
# INFO:sc2.protocol:Client status changed to Status.init_game (was Status.launched)
# INFO:sc2.protocol:Client status changed to Status.in_game (was None)
# INFO:root:Player id: 1
#  0.- self.iteration :  0.000297619047619
#  1.- self.mineral   :  0.0
#  2.- self.vespene   :  0.0
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.075
#  5.- self.units(PROBE)   :  0.06
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.00892857142857
#  1.- self.mineral   :  0.0216666666667
#  2.- self.vespene   :  0.0
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.075
#  5.- self.units(PROBE)   :  0.06
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0175595238095
#  1.- self.mineral   :  0.0183333333333
#  2.- self.vespene   :  0.0
#  3.- self.supply_left :  0.005
#  4.- self.supply_cap  :  0.075
#  5.- self.units(PROBE)   :  0.065
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0261904761905
#  1.- self.mineral   :  0.0166666666667
#  2.- self.vespene   :  0.0
#  3.- self.supply_left :  0.0
#  4.- self.supply_cap  :  0.075
#  5.- self.units(PROBE)   :  0.07
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0348214285714
#  1.- self.mineral   :  0.015
#  2.- self.vespene   :  0.00266666666667
#  3.- self.supply_left :  0.0
#  4.- self.supply_cap  :  0.075
#  5.- self.units(PROBE)   :  0.075
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0434523809524
#  1.- self.mineral   :  0.035
#  2.- self.vespene   :  0.008
#  3.- self.supply_left :  0.0
#  4.- self.supply_cap  :  0.075
#  5.- self.units(PROBE)   :  0.075
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0520833333333
#  1.- self.mineral   :  0.04
#  2.- self.vespene   :  0.012
#  3.- self.supply_left :  0.035
#  4.- self.supply_cap  :  0.115
#  5.- self.units(PROBE)   :  0.075
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0607142857143
#  1.- self.mineral   :  0.0116666666667
#  2.- self.vespene   :  0.016
#  3.- self.supply_left :  0.03
#  4.- self.supply_cap  :  0.115
#  5.- self.units(PROBE)   :  0.075
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0693452380952
#  1.- self.mineral   :  0.0533333333333
#  2.- self.vespene   :  0.02
#  3.- self.supply_left :  0.07
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.085
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0779761904762
#  1.- self.mineral   :  0.101666666667
#  2.- self.vespene   :  0.0226666666667
#  3.- self.supply_left :  0.07
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.08
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0866071428571
#  1.- self.mineral   :  0.153333333333
#  2.- self.vespene   :  0.0266666666667
#  3.- self.supply_left :  0.07
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.085
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.0952380952381
#  1.- self.mineral   :  0.203333333333
#  2.- self.vespene   :  0.0293333333333
#  3.- self.supply_left :  0.07
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.085
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.103869047619
#  1.- self.mineral   :  0.0483333333333
#  2.- self.vespene   :  0.0333333333333
#  3.- self.supply_left :  0.065
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.08
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.1125
#  1.- self.mineral   :  0.0966666666667
#  2.- self.vespene   :  0.0373333333333
#  3.- self.supply_left :  0.065
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.09
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.121130952381
#  1.- self.mineral   :  0.146666666667
#  2.- self.vespene   :  0.04
#  3.- self.supply_left :  0.065
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.09
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.129761904762
#  1.- self.mineral   :  0.11
#  2.- self.vespene   :  0.0106666666667
#  3.- self.supply_left :  0.06
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.085
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.138392857143
#  1.- self.mineral   :  0.158333333333
#  2.- self.vespene   :  0.0146666666667
#  3.- self.supply_left :  0.06
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.095
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.147023809524
#  1.- self.mineral   :  0.205
#  2.- self.vespene   :  0.02
#  3.- self.supply_left :  0.06
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.095
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.155654761905
#  1.- self.mineral   :  0.253333333333
#  2.- self.vespene   :  0.028
#  3.- self.supply_left :  0.06
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.085
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.164285714286
#  1.- self.mineral   :  0.3
#  2.- self.vespene   :  0.036
#  3.- self.supply_left :  0.06
#  4.- self.supply_cap  :  0.155
#  5.- self.units(PROBE)   :  0.095
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.172916666667
#  1.- self.mineral   :  0.275
#  2.- self.vespene   :  0.0163333333333
#  3.- self.supply_left :  0.125
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.09
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.181547619048
#  1.- self.mineral   :  0.305
#  2.- self.vespene   :  0.0243333333333
#  3.- self.supply_left :  0.12
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.095
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.190178571429
#  1.- self.mineral   :  0.335
#  2.- self.vespene   :  0.031
#  3.- self.supply_left :  0.115
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.105
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.19880952381
#  1.- self.mineral   :  0.373333333333
#  2.- self.vespene   :  0.0403333333333
#  3.- self.supply_left :  0.11
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.105
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.0
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.20744047619
#  1.- self.mineral   :  0.161666666667
#  2.- self.vespene   :  0.0483333333333
#  3.- self.supply_left :  0.11
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.105
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.00502512562814
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.216071428571
#  1.- self.mineral   :  0.136666666667
#  2.- self.vespene   :  0.005
#  3.- self.supply_left :  0.1
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.115
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  0.00502512562814
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.224702380952
#  1.- self.mineral   :  0.175
#  2.- self.vespene   :  0.0116666666667
#  3.- self.supply_left :  0.095
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.12
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  7.48802070043e-63
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.233333333333
#  1.- self.mineral   :  0.226666666667
#  2.- self.vespene   :  0.021
#  3.- self.supply_left :  0.09
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.12
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.0
#  8.- len(self.known_enemy_units) #workers  :  1.3947525435e-129
#  9.- len(self.known_enemy_units) #military :  0.0
#  0.- self.iteration :  0.241964285714
#  1.- self.mineral   :  0.276666666667
#  2.- self.vespene   :  0.0316666666667
#  3.- self.supply_left :  0.085
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.13
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.07
#  8.- len(self.known_enemy_units) #workers  :  0.0401256262563
#  9.- len(self.known_enemy_units) #military :  0.005
#  0.- self.iteration :  0.250595238095
#  1.- self.mineral   :  0.328333333333
#  2.- self.vespene   :  0.0423333333333
#  3.- self.supply_left :  0.08
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.135
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0151002537783
#  9.- len(self.known_enemy_units) #military :  1.88760992502e-09
#  0.- self.iteration :  0.259226190476
#  1.- self.mineral   :  0.318333333333
#  2.- self.vespene   :  0.003
#  3.- self.supply_left :  0.07
#  4.- self.supply_cap  :  0.23
#  5.- self.units(PROBE)   :  0.14
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0954018819095
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
#  0.- self.iteration :  0.267857142857
#  1.- self.mineral   :  0.305
#  2.- self.vespene   :  0.0136666666667
#  3.- self.supply_left :  0.14
#  4.- self.supply_cap  :  0.305
#  5.- self.units(PROBE)   :  0.135
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0603015075377
#  9.- len(self.known_enemy_units) #military :  7.48802070043e-63
#  0.- self.iteration :  0.276488095238
#  1.- self.mineral   :  0.0816666666667
#  2.- self.vespene   :  0.0216666666667
#  3.- self.supply_left :  0.205
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.16
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  7.86750294246e-14
#  9.- len(self.known_enemy_units) #military :  0.035175879397
#  0.- self.iteration :  0.285119047619
#  1.- self.mineral   :  0.255
#  2.- self.vespene   :  0.027
#  3.- self.supply_left :  0.19
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.17
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0904523869347
#  9.- len(self.known_enemy_units) #military :  0.035175879397
#  0.- self.iteration :  0.29375
#  1.- self.mineral   :  0.34
#  2.- self.vespene   :  0.035
#  3.- self.supply_left :  0.175
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.175
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0954772613003
#  9.- len(self.known_enemy_units) #military :  4.85223741388e-51
#  0.- self.iteration :  0.302380952381
#  1.- self.mineral   :  0.386666666667
#  2.- self.vespene   :  0.0443333333333
#  3.- self.supply_left :  0.16
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.2
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0100755043876
#  9.- len(self.known_enemy_units) #military :  5.03771984925e-07
#  0.- self.iteration :  0.311011904762
#  1.- self.mineral   :  0.39
#  2.- self.vespene   :  0.005
#  3.- self.supply_left :  0.145
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.215
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  3.72547796936e-65
#  9.- len(self.known_enemy_units) #military :  9.38348444038e-74
#  0.- self.iteration :  0.319642857143
#  1.- self.mineral   :  0.441666666667
#  2.- self.vespene   :  0.0143333333333
#  3.- self.supply_left :  0.13
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.225
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0904773869347
#  9.- len(self.known_enemy_units) #military :  1.74781017758e-140
#  0.- self.iteration :  0.328273809524
#  1.- self.mineral   :  0.541666666667
#  2.- self.vespene   :  0.0236666666667
#  3.- self.supply_left :  0.125
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.23
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0954775125628
#  9.- len(self.known_enemy_units) #military :  0.010050250625
#  0.- self.iteration :  0.336904761905
#  1.- self.mineral   :  0.618333333333
#  2.- self.vespene   :  0.033
#  3.- self.supply_left :  0.115
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.24
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.08
#  8.- len(self.known_enemy_units) #workers  :  0.0100251256281
#  9.- len(self.known_enemy_units) #military :  0.035175879397
#  0.- self.iteration :  0.345535714286
#  1.- self.mineral   :  0.7
#  2.- self.vespene   :  0.0436666666667
#  3.- self.supply_left :  0.095
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.245
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.09
#  8.- len(self.known_enemy_units) #workers  :  0.0954775125597
#  9.- len(self.known_enemy_units) #military :  6.02096768854e-56
#  0.- self.iteration :  0.354166666667
#  1.- self.mineral   :  0.678333333333
#  2.- self.vespene   :  0.00833333333333
#  3.- self.supply_left :  0.055
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.275
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.09
#  8.- len(self.known_enemy_units) #workers  :  0.0301506281438
#  9.- len(self.known_enemy_units) #military :  1.12149262587e-122
#  0.- self.iteration :  0.362797619048
#  1.- self.mineral   :  0.713333333333
#  2.- self.vespene   :  0.0283333333333
#  3.- self.supply_left :  0.035
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.28
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.09
#  8.- len(self.known_enemy_units) #workers  :  0.0201255018813
#  9.- len(self.known_enemy_units) #military :  2.08894279948e-189
#  0.- self.iteration :  0.371428571429
#  1.- self.mineral   :  0.815
#  2.- self.vespene   :  0.0483333333333
#  3.- self.supply_left :  0.02
#  4.- self.supply_cap  :  0.38
#  5.- self.units(PROBE)   :  0.31
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.09
#  8.- len(self.known_enemy_units) #workers  :  0.0553017587908
#  9.- len(self.known_enemy_units) #military :  0.035175879397
#  0.- self.iteration :  0.38005952381
#  1.- self.mineral   :  0.77
#  2.- self.vespene   :  0.0263333333333
#  3.- self.supply_left :  0.045
#  4.- self.supply_cap  :  0.42
#  5.- self.units(PROBE)   :  0.29
#  6.- self.units(VOIDRAY) :  0.0
#  7.- len(self.known_enemy_structures)      :  0.1
#  8.- len(self.known_enemy_units) #workers  :  0.0853517619284
#  9.- len(self.known_enemy_units) #military :  0.035175879397
# [ 0.  1.  0.  0.] attack closer
#  0.- self.iteration :  0.38869047619
#  1.- self.mineral   :  0.813333333333
#  2.- self.vespene   :  0.0176666666667
#  3.- self.supply_left :  0.05
#  4.- self.supply_cap  :  0.42
#  5.- self.units(PROBE)   :  0.29
#  6.- self.units(VOIDRAY) :  0.005
#  7.- len(self.known_enemy_structures)      :  0.1
#  8.- len(self.known_enemy_units) #workers  :  0.0502010031407
#  9.- len(self.known_enemy_units) #military :  0.035175879397
#  0.- self.iteration :  0.397321428571
#  1.- self.mineral   :  0.543333333333
#  2.- self.vespene   :  0.00633333333333
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  0.385
#  5.- self.units(PROBE)   :  0.27
#  6.- self.units(VOIDRAY) :  0.005
#  7.- len(self.known_enemy_structures)      :  0.1
#  8.- len(self.known_enemy_units) #workers  :  6.31281407825e-12
#  9.- len(self.known_enemy_units) #military :  0.0502512562814
#  0.- self.iteration :  0.405952380952
#  1.- self.mineral   :  0.605
#  2.- self.vespene   :  0.0316666666667
#  3.- self.supply_left :  0.005
#  4.- self.supply_cap  :  0.385
#  5.- self.units(PROBE)   :  0.285
#  6.- self.units(VOIDRAY) :  0.005
#  7.- len(self.known_enemy_structures)      :  0.11
#  8.- len(self.known_enemy_units) #workers  :  0.010025125625
#  9.- len(self.known_enemy_units) #military :  0.035175879397
# [ 0.  1.  0.  0.] attack closer
# [ 0.  1.  0.  0.] attack closer
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.414583333333
#  1.- self.mineral   :  0.546666666667
#  2.- self.vespene   :  0.007
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  0.425
#  5.- self.units(PROBE)   :  0.295
#  6.- self.units(VOIDRAY) :  0.01
#  7.- len(self.known_enemy_structures)      :  0.12
#  8.- len(self.known_enemy_units) #workers  :  0.00510063002517
#  9.- len(self.known_enemy_units) #military :  0.0150753768844
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.423214285714
#  1.- self.mineral   :  0.606666666667
#  2.- self.vespene   :  0.035
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.425
#  5.- self.units(PROBE)   :  0.305
#  6.- self.units(VOIDRAY) :  0.01
#  7.- len(self.known_enemy_structures)      :  0.12
#  8.- len(self.known_enemy_units) #workers  :  0.0603015075377
#  9.- len(self.known_enemy_units) #military :  2.52512594221e-05
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.431845238095
#  1.- self.mineral   :  0.661666666667
#  2.- self.vespene   :  0.0183333333333
#  3.- self.supply_left :  0.05
#  4.- self.supply_cap  :  0.465
#  5.- self.units(PROBE)   :  0.305
#  6.- self.units(VOIDRAY) :  0.015
#  7.- len(self.known_enemy_structures)      :  0.12
#  8.- len(self.known_enemy_units) #workers  :  6.16485826887e-33
#  9.- len(self.known_enemy_units) #military :  0.0250502512563
# [ 0.  1.  0.  0.] attack closer
#  0.- self.iteration :  0.440476190476
#  1.- self.mineral   :  0.741666666667
#  2.- self.vespene   :  0.0463333333333
#  3.- self.supply_left :  0.065
#  4.- self.supply_cap  :  0.465
#  5.- self.units(PROBE)   :  0.31
#  6.- self.units(VOIDRAY) :  0.01
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  1.49011611938e-60
#  9.- len(self.known_enemy_units) #military :  0.0150755025126
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.449107142857
#  1.- self.mineral   :  0.706666666667
#  2.- self.vespene   :  0.0376666666667
#  3.- self.supply_left :  0.035
#  4.- self.supply_cap  :  0.465
#  5.- self.units(PROBE)   :  0.31
#  6.- self.units(VOIDRAY) :  0.015
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.0603015075345
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
# [ 0.  0.  0.  1.] attack start location
#  0.- self.iteration :  0.457738095238
#  1.- self.mineral   :  0.73
#  2.- self.vespene   :  0.029
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  0.465
#  5.- self.units(PROBE)   :  0.315
#  6.- self.units(VOIDRAY) :  0.015
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.0100752512563
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
#  0.- self.iteration :  0.466369047619
#  1.- self.mineral   :  0.641666666667
#  2.- self.vespene   :  0.0203333333333
#  3.- self.supply_left :  0.185
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.32
#  6.- self.units(VOIDRAY) :  0.01
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.0553266331658
#  9.- len(self.known_enemy_units) #military :  0.035175879397
#  0.- self.iteration :  0.475
#  1.- self.mineral   :  0.656666666667
#  2.- self.vespene   :  0.0116666666667
#  3.- self.supply_left :  0.165
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.345
#  6.- self.units(VOIDRAY) :  0.01
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.01005
#  9.- len(self.known_enemy_units) #military :  0.0351758800251
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.483630952381
#  1.- self.mineral   :  0.646666666667
#  2.- self.vespene   :  0.00966666666667
#  3.- self.supply_left :  0.15
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.355
#  6.- self.units(VOIDRAY) :  0.01
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.0753767594252
#  9.- len(self.known_enemy_units) #military :  9.72867611066e-47
# [ 0.  0.  0.  1.] attack start location
# [ 0.  1.  0.  0.] attack closer
#  0.- self.iteration :  0.492261904762
#  1.- self.mineral   :  0.63
#  2.- self.vespene   :  0.013
#  3.- self.supply_left :  0.11
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.365
#  6.- self.units(VOIDRAY) :  0.015
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.025125628147
#  9.- len(self.known_enemy_units) #military :  0.0452261306533
# [ 0.  0.  1.  0.] attack structures
# [ 0.  0.  0.  1.] attack start location
#  0.- self.iteration :  0.500892857143
#  1.- self.mineral   :  0.195
#  2.- self.vespene   :  0.006
#  3.- self.supply_left :  0.085
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.385
#  6.- self.units(VOIDRAY) :  0.015
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  7.66773320682e-40
#  9.- len(self.known_enemy_units) #military :  3.76887562971e-07
#  0.- self.iteration :  0.509523809524
#  1.- self.mineral   :  0.07
#  2.- self.vespene   :  0.0253333333333
#  3.- self.supply_left :  0.055
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.4
#  6.- self.units(VOIDRAY) :  0.015
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  3.92587890625e-19
#  9.- len(self.known_enemy_units) #military :  7.02007790974e-74
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.518154761905
#  1.- self.mineral   :  0.0566666666667
#  2.- self.vespene   :  0.042
#  3.- self.supply_left :  0.035
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.41
#  6.- self.units(VOIDRAY) :  0.02
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  1.53354663945e-37
#  9.- len(self.known_enemy_units) #military :  0.0501756262563
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.526785714286
#  1.- self.mineral   :  0.123333333333
#  2.- self.vespene   :  0.111333333333
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.655
#  5.- self.units(PROBE)   :  0.44
#  6.- self.units(VOIDRAY) :  0.025
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.00502512562814
#  9.- len(self.known_enemy_units) #military :  0.0351760050251
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.535416666667
#  1.- self.mineral   :  0.0733333333333
#  2.- self.vespene   :  0.0806666666667
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.695
#  5.- self.units(PROBE)   :  0.465
#  6.- self.units(VOIDRAY) :  0.03
#  7.- len(self.known_enemy_structures)      :  0.13
#  8.- len(self.known_enemy_units) #workers  :  0.0201256281376
#  9.- len(self.known_enemy_units) #military :  0.0201005025157
# [ 0.  1.  0.  0.] attack closer
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.544047619048
#  1.- self.mineral   :  0.235
#  2.- self.vespene   :  0.155333333333
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.695
#  5.- self.units(PROBE)   :  0.46
#  6.- self.units(VOIDRAY) :  0.035
#  7.- len(self.known_enemy_structures)      :  0.14
#  8.- len(self.known_enemy_units) #workers  :  0.00502512562816
#  9.- len(self.known_enemy_units) #military :  2.45367462465e-28
#  0.- self.iteration :  0.552678571429
#  1.- self.mineral   :  0.0633333333333
#  2.- self.vespene   :  0.0286666666667
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.735
#  5.- self.units(PROBE)   :  0.465
#  6.- self.units(VOIDRAY) :  0.035
#  7.- len(self.known_enemy_structures)      :  0.14
#  8.- len(self.known_enemy_units) #workers  :  0.0201003775126
#  9.- len(self.known_enemy_units) #military :  9.81469849246e-24
#  0.- self.iteration :  0.56130952381
#  1.- self.mineral   :  0.223333333333
#  2.- self.vespene   :  0.107333333333
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.735
#  5.- self.units(PROBE)   :  0.465
#  6.- self.units(VOIDRAY) :  0.035
#  7.- len(self.known_enemy_structures)      :  0.15
#  8.- len(self.known_enemy_units) #workers  :  0.050201004397
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
# [ 0.  0.  0.  1.] attack start location
#  0.- self.iteration :  0.56994047619
#  1.- self.mineral   :  0.188333333333
#  2.- self.vespene   :  0.0846666666667
#  3.- self.supply_left :  0.01
#  4.- self.supply_cap  :  0.775
#  5.- self.units(PROBE)   :  0.465
#  6.- self.units(VOIDRAY) :  0.045
#  7.- len(self.known_enemy_structures)      :  0.16
#  8.- len(self.known_enemy_units) #workers  :  0.070351254397
#  9.- len(self.known_enemy_units) #military :  0.00502525125628
#  0.- self.iteration :  0.578571428571
#  1.- self.mineral   :  0.00833333333333
#  2.- self.vespene   :  0.058
#  3.- self.supply_left :  0.175
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.455
#  6.- self.units(VOIDRAY) :  0.045
#  7.- len(self.known_enemy_structures)      :  0.17
#  8.- len(self.known_enemy_units) #workers  :  0.140703518844
#  9.- len(self.known_enemy_units) #military :  0.0150752512563
# [ 0.  0.  0.  1.] attack start location
# [ 0.  1.  0.  0.] attack closer
#  0.- self.iteration :  0.587202380952
#  1.- self.mineral   :  0.0883333333333
#  2.- self.vespene   :  0.034
#  3.- self.supply_left :  0.135
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.46
#  6.- self.units(VOIDRAY) :  0.055
#  7.- len(self.known_enemy_structures)      :  0.16
#  8.- len(self.known_enemy_units) #workers  :  0.115552890075
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
#  0.- self.iteration :  0.595833333333
#  1.- self.mineral   :  0.111666666667
#  2.- self.vespene   :  0.006
#  3.- self.supply_left :  0.115
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.455
#  6.- self.units(VOIDRAY) :  0.055
#  7.- len(self.known_enemy_structures)      :  0.14
#  8.- len(self.known_enemy_units) #workers  :  0.0904523869378
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
# [ 0.  0.  1.  0.] attack structures
#  0.- self.iteration :  0.604464285714
#  1.- self.mineral   :  0.2
#  2.- self.vespene   :  0.0413333333333
#  3.- self.supply_left :  0.095
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.45
#  6.- self.units(VOIDRAY) :  0.065
#  7.- len(self.known_enemy_structures)      :  0.12
#  8.- len(self.known_enemy_units) #workers  :  0.0954773869347
#  9.- len(self.known_enemy_units) #military :  0.00502512563128
# [ 0.  1.  0.  0.] attack closer
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.613095238095
#  1.- self.mineral   :  0.211666666667
#  2.- self.vespene   :  0.0306666666667
#  3.- self.supply_left :  0.055
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.45
#  6.- self.units(VOIDRAY) :  0.08
#  7.- len(self.known_enemy_structures)      :  0.11
#  8.- len(self.known_enemy_units) #workers  :  0.0753768850503
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
# [ 0.  0.  0.  1.] attack start location
# [ 0.  0.  0.  1.] attack start location
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.621726190476
#  1.- self.mineral   :  0.183333333333
#  2.- self.vespene   :  0.0146666666667
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.475
#  6.- self.units(VOIDRAY) :  0.09
#  7.- len(self.known_enemy_structures)      :  0.09
#  8.- len(self.known_enemy_units) #workers  :  0.0603267587971
#  9.- len(self.known_enemy_units) #military :  0.00502512562814
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.630357142857
#  1.- self.mineral   :  0.306666666667
#  2.- self.vespene   :  0.0406666666667
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.45
#  6.- self.units(VOIDRAY) :  0.09
#  7.- len(self.known_enemy_structures)      :  0.07
#  8.- len(self.known_enemy_units) #workers  :  0.0301508800283
#  9.- len(self.known_enemy_units) #military :  0.005025
# [ 0.  0.  0.  1.] attack start location
# [ 0.  1.  0.  0.] attack closer
# [ 0.  0.  0.  1.] attack start location
# [ 0.  1.  0.  0.] attack closer
#  0.- self.iteration :  0.638988095238
#  1.- self.mineral   :  0.44
#  2.- self.vespene   :  0.119333333333
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.46
#  6.- self.units(VOIDRAY) :  0.1
#  7.- len(self.known_enemy_structures)      :  0.05
#  8.- len(self.known_enemy_units) #workers  :  0.0301507537688
#  9.- len(self.known_enemy_units) #military :  7.4880207004e-63
# [ 0.  0.  1.  0.] attack structures
# [ 0.  0.  0.  1.] attack start location
# [ 0.  0.  0.  1.] attack start location
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.647619047619
#  1.- self.mineral   :  0.606666666667
#  2.- self.vespene   :  0.203333333333
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.455
#  6.- self.units(VOIDRAY) :  0.11
#  7.- len(self.known_enemy_structures)      :  0.05
#  8.- len(self.known_enemy_units) #workers  :  0.0251256281407
#  9.- len(self.known_enemy_units) #military :  1.39475254349e-129
# [ 0.  1.  0.  0.] attack closer
# [ 1.  0.  0.  0.] nothing
#  0.- self.iteration :  0.65625
#  1.- self.mineral   :  0.741666666667
#  2.- self.vespene   :  0.29
#  3.- self.supply_left :  0.015
#  4.- self.supply_cap  :  1.0
#  5.- self.units(PROBE)   :  0.46
#  6.- self.units(VOIDRAY) :  0.12
#  7.- len(self.known_enemy_structures)      :  0.03
#  8.- len(self.known_enemy_units) #workers  :  2.45373596805e-28
#  9.- len(self.known_enemy_units) #military :  2.59792905952e-196
# [ 0.  1.  0.  0.] attack closer
# INFO:sc2.protocol:Client status changed to Status.ended (was Status.in_game)
# --- on_end called ---
# Result:  Result.Victory
# INFO:root:Result for player id: 1: Result.Victory
# INFO:sc2.protocol:Client status changed to Status.launched (was Status.ended)
# INFO:sc2.protocol:Client status changed to Status.quit (was Status.launched)
# INFO:sc2.sc2process:kill_switch: Process cleanup
# INFO:sc2.sc2process:Cleaning up...
# INFO:sc2.sc2process:Cleanup complete
# INFO:sc2.sc2process:Cleaning up...
# INFO:sc2.sc2process:Cleanup complete
# INFO:sc2.sc2process:Cleaning up...
# INFO:sc2.sc2process:Cleanup complete
# INFO:sc2.sc2process:Cleaning up...
# INFO:sc2.sc2process:Cleanup complete
# INFO:sc2.sc2process:Cleaning up...
# INFO:sc2.sc2process:Cleanup complete
# <Result.Victory: 1>
